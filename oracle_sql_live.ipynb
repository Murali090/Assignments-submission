# %%
import pandas

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0,10,56,80,90,100])
ypoints = np.array([0,5,20,64,95,10000])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y=np.array([35,45,78,90,100])

plt.pie(y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 90])
mylables=["apples","grapes","oranges"]
mycolours=["#4dffff","#c18d0b","#ff0000"]

plt.pie(y,labels = mylables,colors = mycolours )
plt.legend()
plt.show()

# %%
                                                                                                                                                        import matplotlib.pyplot as pltimport numpy as np
 import matplotlib.pyplot()
x = np.array(["mech", "clad", "maths", "ohysics"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y,color = "#4dffc3")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np 

x=np.array([50,40,60,80])

plt.pie(x)
plt.show()

# %%
import matplotlib.pyplot  as plot
import numpy as np

x=np.array(["mech","physics","red","lol"])
y=np.array([3,8,1,10])

plt.plot(x,y,"#4dffc3")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array([30,20,50])
y=np.array(["murali","venky","pinky"])

plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array([30,20,50])

plt.pie(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array([30,70,80,55])

plt.pie(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.1, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()
