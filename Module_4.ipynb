# %%
#PYPLOT
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([0, 90])
ypoints = np.array([0,150])

plt.plot(xpoints, ypoints)
plt.show()

# %%
#PLOTTING
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([5, 10,15])
ypoints = np.array([40, 56,65])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([10,50,89])
ypoints = np.array([2,45,69])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([10,56,78])
ypoints = np.array([5,50,69])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([20, 18,50])
ypoints = np.array([23,56,69])

plt.plot(xpoints, ypoints)
plt.show()

# %%
#MARKERS
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([20, 18,50])
ypoints = np.array([23,56,69])

plt.plot(xpoints, ypoints,marker = 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([10,56,78])
ypoints = np.array([5,50,69])

plt.plot(xpoints, ypoints,marker = 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([10,50,89])
ypoints = np.array([2,45,69])

plt.plot(xpoints, ypoints,marker = 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([0, 90])
ypoints = np.array([0,150])

plt.plot(xpoints, ypoints,marker = 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([5, 10,15])
ypoints = np.array([40, 56,65])

plt.plot(xpoints, ypoints,marker = 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([5, 18, 10, 100])

plt.plot(ypoints, marker = '+')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([5, 18, 10, 100])

plt.plot(ypoints, marker = 'd')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([5, 18, 10, 100])

plt.plot(ypoints, marker = 'd')
plt.show()

# %%
#LINE GRAPH
import matplotlib.pyplot as plt
import numpy as np

xpoints=np.array([5,7,8,90])

plt.plot(xpoints,linestyle=':')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np 

xpoints=np.array([4,56,78,90])

plt.plot(xpoints,linestyle='--')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np 

xpoints=np.array([3,6,1,3,7,89,105,150])

plt.plot(xpoints,linestyle='-.')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np 

xpoints=np.array([6,67,78,98,100])

plt.plot(xpoints,linestyle=	'' or ' ')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np 

xpoints=np.array([56,78,87,45,32])

plt.plot(xpoints,linestyle=":")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np 

xpoints=np.array([78,98,45,21,45])

plt.plot(xpoints,linestyle="-.")
plt.show()

# %%
#LABELS
import numpy as np
import matplotlib.pyplot as plt

x = np.array([26,56,87,90,150,76])
y = np.array([56,76,45,32,98,100])

plt.plot(x, y)

plt.xlabel("fat")
plt.ylabel("burned")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([25,50,75,100,125,150,175,200])
y = np.array([500,550,575,600,625,650,675,700])

plt.xlabel("horse power")
plt.ylabel("torque")

plt.plot(x, y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("cars manufactures", loc = 'left')
plt.xlabel("cars manufactures names ")
plt.ylabel("horse power")

plt.plot(x, y)
plt.show()

# %%
#GRIDS
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("cars manufactures", loc = 'left')
plt.xlabel("cars manufactures names ")
plt.ylabel("horse power")

plt.plot(x, y)
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([25,50,75,100,125,150,175,200])
y = np.array([500,550,575,600,625,650,675,700])

plt.xlabel("horse power")
plt.ylabel("torque")

plt.plot(x, y)
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([26,56,87,90,150,76])
y = np.array([56,76,45,32,98,100])

plt.plot(x, y)

plt.xlabel("fat")
plt.ylabel("burned")

plt.grid()

plt.show()

# %%
#SUBPLOT
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0,50,100,150])
y = np.array([25,75,89,65])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0,50,100,150])
y = np.array([25,75,89,500])

plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([25,75,89,500])
y = np.array([0,50,100,150])

plt.subplot(2, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0,50,100,150])
y = np.array([25,75,89,500])

plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([25,75,89,500])
y = np.array([0,50,100,150])

plt.subplot(2, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array([18,52,56,70,80])
y = np.array([25,75,89,100,150])

plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %%
# SCATTER
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([26,56,87,90,150,76])
y = np.array([56,76,45,32,98,100])

plt.scatter(x,y)


plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.scatter(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.scatter(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


x = np.array([0,50,100,150])
y = np.array([25,75,89,500])

plt.scatter(x,y)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([26,56,87,90,150,76])
y = np.array([56,76,45,32,98,100])

plt.scatter(x, y)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([25,50,75,100,125,150,175,200])
y = np.array([500,550,575,600,625,650,675,700])
 
plt.scatter(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.scatter(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#day one, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

#day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

plt.show()

# %%
#BARS
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([25,50,75,80])
y = np.array([50,55,755,60])
 
plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([1,3,2,4,5,])
y = np.array([2,4,3,2,2])


plt.bar(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])


plt.bar(x,y)

plt.show()

# %%
#HISTOGRAM
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(100, 100, 250)

plt.hist(x,colors = "#7FFF00")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-02dbeeafbda8> in <module>()
#       4 x = np.random.normal(100, 100, 250)
#       5
# ----> 6 plt.hist(x,colors = "#7FFF00")
#       7 plt.show()
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2608         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2609         color=color, label=label, stacked=stacked, **({"data": data}
# -> 2610         if data is not None else {}), **kwargs)
#    2611
#    2612
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# ...

# %%
#PIECHARTS
import matplotlib.pyplot as plt
import numpy as np

x=np.array([30,20,50,100,40,59,60])

plt.pie(x,)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array([30,70,80,55])
mylabels=(["A","B","C","D"])

plt.pie(x,labels=mylabels)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array([30,20,50])

plt.pie(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np 

x=np.array([50,40,60,80])

plt.pie(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 90])

mycolours=["#4dffff","#c18d0b","#ff0000"]

plt.pie(y,colors = mycolours )
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
import matplotlib.pyplot as plt
import numpy as np

y=np.array([35,45,78,90,100])

plt.pie(y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])

mycolors = ["black", "hotpink", "b", "#4CAF50"]

plt.pie(y, colors = mycolors)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])


plt.pie(y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y=np.array([67,90,43,21,68,90,87,56])

plt.pie(y)
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np

xpoints=np.array([30,56,36])
ypionts=np.array([45,85,98])

plt.pie(xpoints,)
plt.show()
